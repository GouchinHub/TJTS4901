# %%
import pandas as pd
import numpy as np
import psycopg2

# %%
def luo_yhteys():
    try:
        connection = psycopg2.connect(
            host="192.168.0.15",
            database="VehicleRegisterDatabase",
            user="postgres",
            password="1337"
        )
        #print("Connection to PostgreSQL database successful")
        print(connection)
    except (Exception, psycopg2.Error) as error:
        print("Error while connecting to PostgreSQL database:", error)

    try:
        cursor = connection.cursor()
        print("Cursor created successfully")
    except (Exception, psycopg2.Error) as error:
        print("Error while creating a cursor:", error)

    return cursor

# %%
cursor = luo_yhteys()
query = f'''
    SELECT kunta, ajoneuvoluokka, ensirekisterointipvm
    FROM ajoneuvorekisteroinnit
    WHERE kunta = '179' AND ajoneuvoluokka = 'M1' AND ensirekisterointipvm >= '2010-01-01' AND ensirekisterointipvm <= '2022-01-01'
    ORDER BY ensirekisterointipvm
'''
try:
    cursor.execute(query)
    # Fetch and print the results
    records = cursor.fetchall()
    df = pd.DataFrame(records, columns=["kunta", "ajoneuvoluokka", "ensirekisterointopvm"])
    print(df)

    # Commit the transaction
    #connection.commit()
except (Exception, psycopg2.Error) as error:
    print("Error while executing SQL query:", error)
# Out:
# <connection object at 0x000002732D69B670; dsn: 'user=postgres password=xxx dbname=VehicleRegisterDatabase host=192.168.0.15', closed: 0>
# Cursor created successfully
#        kunta ajoneuvoluokka ensirekisterointopvm
# 0        179             M1           2010-01-02
# 1        179             M1           2010-01-02
# 2        179             M1           2010-01-02
# 3        179             M1           2010-01-04
# 4        179             M1           2010-01-04
# ...      ...            ...                  ...
# 20276    179             M1           2020-05-07
# 20277    179             M1           2020-08-20
# 20278    179             M1           2021-05-18
# 20279    179             M1           2021-07-23
# 20280    179             M1           2021-11-01
#
# [20281 rows x 3 columns]

# %%
def ensirekisteroinnit_kunnittain_ajoneuvoluokassa(pvm_alku, pvm_loppu, ajoneuvoluokka, kunta, hae_malleittain):
    cursor = luo_yhteys()
    query = f''' SELECT ar.merkkiselvakielinen, '''
    if(hae_malleittain):
        query += f'''ar.mallimerkinta,'''
    query += f'''
        COUNT(ar.id) AS maara
        FROM ajoneuvorekisteroinnit ar
        LEFT JOIN kunta ku ON ku.id = ar.kunta
        WHERE ku.selite_fi = '{kunta.title()}' AND ar.ajoneuvoluokka = '{ajoneuvoluokka}' AND ensirekisterointipvm >= '{pvm_alku}' AND ensirekisterointipvm <= '{pvm_loppu}'
		GROUP BY ar.merkkiselvakielinen 
    '''
    if(hae_malleittain):
        query += f''', ar.mallimerkinta'''

    query += f'''
        ORDER BY maara DESC;
    '''
    try:
        cursor.execute(query)
        # Fetch and print the results
        records = cursor.fetchall()
        columns = ["Merkki", "Määrä"]
        if (hae_malleittain):
            columns.insert(1, "Malli")
        
        df = pd.DataFrame(records, columns=columns)

        return df
        # Commit the transaction
        #connection.commit()
    except (Exception, psycopg2.Error) as error:
        print("Error while executing SQL query:", error)

# %%
ensirekisteroinnit_kunnittain_ajoneuvoluokassa('2016-01-01', '2017-01-01', 'M1', 'Helsinki', True)
# Out:
# <connection object at 0x000002734524D470; dsn: 'user=postgres password=xxx dbname=VehicleRegisterDatabase host=192.168.0.15', closed: 0>
# Cursor created successfully
#               Merkki                                              Malli  Määrä
# 0             Nissan  Nissan Qashqai Monikäyttöajoneuvo (AF) 4ov 119...    298
# 1             Toyota   TOYOTA AURIS Monikäyttöajoneuvo (AF) 4ov 1798cm3    238
# 2     Volkswagen, VW                      GOLF Farmari (AC) 5ov 1197cm3    177
# 3             Toyota   TOYOTA YARIS Monikäyttöajoneuvo (AF) 4ov 1329cm3    163
# 4               Ford                  Fiesta Viistoperä (AB) 4ov 998cm3    160
# ...              ...                                                ...    ...
# 1827            Saab                       9-3 Farmari (AC) 4ov 1998cm3      1
# 1828            Saab                     9-3 Farmari (AC) 4ov 2792cm3 A      1
# 1829            Saab                         9-3 Sedan (AA) 4ov 1990cm3      1
# 1830            Saab                       9-3 Sedan (AA) 4ov 1990cm3 A      1
# 1831            Saab                       9-5 Farmari (AC) 4ov 2290cm3      1
#
# [1832 rows x 3 columns]

# %%
def hybridiautot_luokittain(luokka, vuosi_alku, vuosi_loppu,):
    cursor = luo_yhteys()
    query = f'''
        SELECT EXTRACT(YEAR FROM ar.ensirekisterointipvm), EXTRACT(MONTH FROM ar.ensirekisterointipvm), hl.lyhytselite_fi, COUNT(ar.*)
        FROM ajoneuvorekisteroinnit ar
    	LEFT JOIN hybridiluokka hl ON hl.id = ar.sahkohybridinluokka
        WHERE ar.sahkohybridi = true
        AND ar.ajoneuvoluokka = '{luokka}' 
        AND ar.ensirekisterointipvm >= '{str(vuosi_alku)}-1-1' 
        AND ar.ensirekisterointipvm <= '{str(vuosi_loppu)}-12-31'
        GROUP BY EXTRACT(YEAR FROM ar.ensirekisterointipvm), EXTRACT(MONTH FROM ar.ensirekisterointipvm), hl.lyhytselite_fi
        ORDER BY EXTRACT(YEAR FROM ar.ensirekisterointipvm) DESC, EXTRACT(MONTH FROM ar.ensirekisterointipvm) DESC, hl.lyhytselite_fi
    '''
    try:
        cursor.execute(query)
        # Fetch and print the results
        records = cursor.fetchall()
        df = pd.DataFrame(records, columns=["vuosi", "kuukausi", "hybridityyppi", "maara"])
        df.fillna("Ei määritelty", inplace=True)

        return df
        # Commit the transaction
        #connection.commit()
    except (Exception, psycopg2.Error) as error:
        print("Error while executing SQL query:", error)

# %%
import matplotlib.pyplot as plt

df = hybridiautot_luokittain('M1', 2010, 2017)
df['date'] = df["kuukausi"].astype('str') + '.' + df["vuosi"].astype('str')

pd.set_option('display.max_rows', None)
print(df)
print(df1)
print(df2)

df1 = df[df['hybridityyppi'] == 'Sähköverkosta ladattava']
plt.plot(df1['date'], df1['maara'], label='Type 1')

df2 = df[df['hybridityyppi'] == 'Pelkästään polttomoottorilla ladattava']
plt.plot(df2['date'], df2['maara'], label='Type 2')

plt.show()
# Out:
# <connection object at 0x000002734941E790; dsn: 'user=postgres password=xxx dbname=VehicleRegisterDatabase host=192.168.0.15', closed: 0>
# Cursor created successfully
#     vuosi kuukausi                           hybridityyppi  maara     date
# 0    2017       12  Pelkästään polttomoottorilla ladattava      4  12.2017
# 1    2017       12                 Sähköverkosta ladattava      2  12.2017
# 2    2017       11  Pelkästään polttomoottorilla ladattava      4  11.2017
# 3    2017       11                 Sähköverkosta ladattava      1  11.2017
# 4    2017       10  Pelkästään polttomoottorilla ladattava      8  10.2017
# 5    2017       10                 Sähköverkosta ladattava      2  10.2017
# 6    2017        9  Pelkästään polttomoottorilla ladattava     22   9.2017
# 7    2017        9                 Sähköverkosta ladattava      4   9.2017
# 8    2017        8  Pelkästään polttomoottorilla ladattava     32   8.2017
# 9    2017        8                 Sähköverkosta ladattava      8   8.2017
# 10   2017        7  Pelkästään polttomoottorilla ladattava     20   7.2017
# 11   2017        7                 Sähköverkosta ladattava      7   7.2017
# 12   2017        6  Pelkästään polttomoottorilla ladattava     31   6.2017
# 13   2017        6                 Sähköverkosta ladattava      5   6.2017
# 14   2017        5  Pelkästään polttomoottorilla ladattava     30   5.2017
# 15   2017        5                 Sähköverkosta ladattava     19   5.2017
# 16   2017        4  Pelkästään polttomoottorilla ladattava     42   4.2017
# 17   2017        4                 Sähköverkosta ladattava     16   4.2017
# 18   2017        3  Pelkästään polttomoottorilla ladattava    130   3.2017
# 19   2017        3                 Sähköverkosta ladattava     17   3.2017
# 20   2017        2  Pelkästään polttomoottorilla ladattava     89   2.2017
# 21   2017        2                 Sähköverkosta ladattava     21   2.2017
# 22   2017        1  Pelkästään polttomoottorilla ladattava    290   1.2017
# 23   2017        1                 Sähköverkosta ladattava     56   1.2017
# 24   2016       12  Pelkästään polttomoottorilla ladattava    288  12.2016
# 25   2016       12                 Sähköverkosta ladattava     62  12.2016
# 26   2016       11  Pelkästään polttomoottorilla ladattava    429  11.2016
# 27   2016       11                 Sähköverkosta ladattava     86  11.2016
# 28   2016       10  Pelkästään polttomoottorilla ladattava    417  10.2016
# 29   2016       10                 Sähköverkosta ladattava     86  10.2016
# 30   2016        9  Pelkästään polttomoottorilla ladattava    449   9.2016
# 31   2016        9                 Sähköverkosta ladattava     82   9.2016
# 32   2016        8  Pelkästään polttomoottorilla ladattava    478   8.2016
# 33   2016        8                 Sähköverkosta ladattava     64   8.2016
# 34   2016        7  Pelkästään polttomoottorilla ladattava    311   7.2016
# 35   2016        7                 Sähköverkosta ladattava     68   7.2016
# 36   2016        6  Pelkästään polttomoottorilla ladattava    450   6.2016
# 37   2016        6                 Sähköverkosta ladattava     64   6.2016
# 38   2016        5  Pelkästään polttomoottorilla ladattava    440   5.2016
# 39   2016        5                 Sähköverkosta ladattava     60   5.2016
# 40   2016        4  Pelkästään polttomoottorilla ladattava    401   4.2016
# 41   2016        4                 Sähköverkosta ladattava     56   4.2016
# 42   2016        3  Pelkästään polttomoottorilla ladattava    457   3.2016
# 43   2016        3                 Sähköverkosta ladattava     59   3.2016
# 44   2016        2  Pelkästään polttomoottorilla ladattava    320   2.2016
# 45   2016        2                 Sähköverkosta ladattava     74   2.2016
# 46   2016        1  Pelkästään polttomoottorilla ladattava    361   1.2016
# 47   2016        1                 Sähköverkosta ladattava     35   1.2016
# 48   2015       12  Pelkästään polttomoottorilla ladattava    258  12.2015
# 49   2015       12                 Sähköverkosta ladattava     36  12.2015
# 50   2015       11  Pelkästään polttomoottorilla ladattava    345  11.2015
# 51   2015       11                 Sähköverkosta ladattava     32  11.2015
# 52   2015       10  Pelkästään polttomoottorilla ladattava    305  10.2015
# 53   2015       10                 Sähköverkosta ladattava     34  10.2015
# 54   2015        9  Pelkästään polttomoottorilla ladattava    248   9.2015
# 55   2015        9                 Sähköverkosta ladattava     40   9.2015
# 56   2015        8  Pelkästään polttomoottorilla ladattava    239   8.2015
# 57   2015        8                 Sähköverkosta ladattava     37   8.2015
# 58   2015        7  Pelkästään polttomoottorilla ladattava    161   7.2015
# 59   2015        7                 Sähköverkosta ladattava     29   7.2015
# 60   2015        6  Pelkästään polttomoottorilla ladattava    196   6.2015
# 61   2015        6                 Sähköverkosta ladattava     35   6.2015
# 62   2015        5  Pelkästään polttomoottorilla ladattava    256   5.2015
# 63   2015        5                 Sähköverkosta ladattava     38   5.2015
# 64   2015        4  Pelkästään polttomoottorilla ladattava    270   4.2015
# 65   2015        4                 Sähköverkosta ladattava     38   4.2015
# 66   2015        3  Pelkästään polttomoottorilla ladattava    299   3.2015
# 67   2015        3                 Sähköverkosta ladattava     21   3.2015
# 68   2015        2  Pelkästään polttomoottorilla ladattava    199   2.2015
# 69   2015        2                 Sähköverkosta ladattava     15   2.2015
# 70   2015        1  Pelkästään polttomoottorilla ladattava    216   1.2015
# 71   2015        1                 Sähköverkosta ladattava     16   1.2015
# 72   2014       12  Pelkästään polttomoottorilla ladattava    183  12.2014
# 73   2014       12                 Sähköverkosta ladattava     24  12.2014
# 74   2014       11  Pelkästään polttomoottorilla ladattava    235  11.2014
# 75   2014       11                 Sähköverkosta ladattava     19  11.2014
# 76   2014       10  Pelkästään polttomoottorilla ladattava    227  10.2014
# 77   2014       10                 Sähköverkosta ladattava     23  10.2014
# 78   2014        9  Pelkästään polttomoottorilla ladattava    248   9.2014
# 79   2014        9                 Sähköverkosta ladattava     19   9.2014
# 80   2014        8  Pelkästään polttomoottorilla ladattava    221   8.2014
# 81   2014        8                 Sähköverkosta ladattava     23   8.2014
# 82   2014        7  Pelkästään polttomoottorilla ladattava    129   7.2014
# 83   2014        7                 Sähköverkosta ladattava     18   7.2014
# 84   2014        6  Pelkästään polttomoottorilla ladattava    169   6.2014
# 85   2014        6                 Sähköverkosta ladattava     20   6.2014
# 86   2014        5  Pelkästään polttomoottorilla ladattava    201   5.2014
# 87   2014        5                 Sähköverkosta ladattava     17   5.2014
# 88   2014        4  Pelkästään polttomoottorilla ladattava    145   4.2014
# 89   2014        4                 Sähköverkosta ladattava     26   4.2014
# 90   2014        3  Pelkästään polttomoottorilla ladattava    185   3.2014
# 91   2014        3                 Sähköverkosta ladattava     38   3.2014
# 92   2014        2  Pelkästään polttomoottorilla ladattava    151   2.2014
# 93   2014        2                 Sähköverkosta ladattava     10   2.2014
# 94   2014        1  Pelkästään polttomoottorilla ladattava    266   1.2014
# 95   2014        1                 Sähköverkosta ladattava     19   1.2014
# 96   2013       12  Pelkästään polttomoottorilla ladattava     92  12.2013
# 97   2013       12                 Sähköverkosta ladattava     19  12.2013
# 98   2013       12                           Ei määritelty      2  12.2013
# 99   2013       11  Pelkästään polttomoottorilla ladattava    218  11.2013
# 100  2013       11                 Sähköverkosta ladattava     36  11.2013
# 101  2013       11                           Ei määritelty      2  11.2013
# 102  2013       10  Pelkästään polttomoottorilla ladattava    301  10.2013
# 103  2013       10                 Sähköverkosta ladattava     20  10.2013
# 104  2013       10                           Ei määritelty      1  10.2013
# 105  2013        9  Pelkästään polttomoottorilla ladattava    128   9.2013
# 106  2013        9                 Sähköverkosta ladattava      8   9.2013
# 107  2013        9                           Ei määritelty      1   9.2013
# 108  2013        8  Pelkästään polttomoottorilla ladattava    225   8.2013
# 109  2013        8                 Sähköverkosta ladattava      3   8.2013
# 110  2013        8                           Ei määritelty      1   8.2013
# 111  2013        7  Pelkästään polttomoottorilla ladattava    239   7.2013
# 112  2013        7                 Sähköverkosta ladattava      6   7.2013
# 113  2013        7                           Ei määritelty      1   7.2013
# 114  2013        6  Pelkästään polttomoottorilla ladattava    138   6.2013
# 115  2013        6                 Sähköverkosta ladattava      5   6.2013
# 116  2013        5  Pelkästään polttomoottorilla ladattava    182   5.2013
# 117  2013        5                 Sähköverkosta ladattava      2   5.2013
# 118  2013        4  Pelkästään polttomoottorilla ladattava    151   4.2013
# 119  2013        4                 Sähköverkosta ladattava     13   4.2013
# 120  2013        3  Pelkästään polttomoottorilla ladattava    174   3.2013
# 121  2013        3                 Sähköverkosta ladattava     21   3.2013
# 122  2013        2  Pelkästään polttomoottorilla ladattava    177   2.2013
# 123  2013        2                 Sähköverkosta ladattava     11   2.2013
# 124  2013        2                           Ei määritelty      1   2.2013
# 125  2013        1  Pelkästään polttomoottorilla ladattava    196   1.2013
# 126  2013        1                 Sähköverkosta ladattava     10   1.2013
# 127  2013        1                           Ei määritelty      1   1.2013
# 128  2012       12  Pelkästään polttomoottorilla ladattava     93  12.2012
# 129  2012       12                 Sähköverkosta ladattava      4  12.2012
# 130  2012       11  Pelkästään polttomoottorilla ladattava    138  11.2012
# 131  2012       11                 Sähköverkosta ladattava      6  11.2012
# 132  2012       10  Pelkästään polttomoottorilla ladattava    160  10.2012
# 133  2012       10                 Sähköverkosta ladattava      7  10.2012
# 134  2012        9  Pelkästään polttomoottorilla ladattava     98   9.2012
# 135  2012        9                 Sähköverkosta ladattava     35   9.2012
# 136  2012        8  Pelkästään polttomoottorilla ladattava    137   8.2012
# 137  2012        8                 Sähköverkosta ladattava     24   8.2012
# 138  2012        7  Pelkästään polttomoottorilla ladattava    126   7.2012
# 139  2012        7                 Sähköverkosta ladattava     12   7.2012
# 140  2012        6  Pelkästään polttomoottorilla ladattava    113   6.2012
# 141  2012        6                 Sähköverkosta ladattava      7   6.2012
# 142  2012        5  Pelkästään polttomoottorilla ladattava     75   5.2012
# 143  2012        5                 Sähköverkosta ladattava     15   5.2012
# 144  2012        4  Pelkästään polttomoottorilla ladattava    120   4.2012
# 145  2012        4                 Sähköverkosta ladattava      4   4.2012
# 146  2012        3  Pelkästään polttomoottorilla ladattava    105   3.2012
# 147  2012        2  Pelkästään polttomoottorilla ladattava     51   2.2012
# 148  2012        2                 Sähköverkosta ladattava      4   2.2012
# 149  2012        1  Pelkästään polttomoottorilla ladattava    101   1.2012
# 150  2011       12  Pelkästään polttomoottorilla ladattava     38  12.2011
# 151  2011       11  Pelkästään polttomoottorilla ladattava     76  11.2011
# 152  2011       11                           Ei määritelty      1  11.2011
# 153  2011       10  Pelkästään polttomoottorilla ladattava     84  10.2011
# 154  2011       10                           Ei määritelty      1  10.2011
# 155  2011        9  Pelkästään polttomoottorilla ladattava    123   9.2011
# 156  2011        8  Pelkästään polttomoottorilla ladattava     66   8.2011
# 157  2011        7  Pelkästään polttomoottorilla ladattava     53   7.2011
# 158  2011        6  Pelkästään polttomoottorilla ladattava     52   6.2011
# 159  2011        5  Pelkästään polttomoottorilla ladattava    104   5.2011
# 160  2011        4  Pelkästään polttomoottorilla ladattava     84   4.2011
# 161  2011        3  Pelkästään polttomoottorilla ladattava    118   3.2011
# 162  2011        2  Pelkästään polttomoottorilla ladattava     50   2.2011
# 163  2011        1  Pelkästään polttomoottorilla ladattava     61   1.2011
# 164  2010       12  Pelkästään polttomoottorilla ladattava    104  12.2010
# 165  2010       12                 Sähköverkosta ladattava      1  12.2010
# 166  2010       12                           Ei määritelty      1  12.2010
# 167  2010       11  Pelkästään polttomoottorilla ladattava    106  11.2010
# 168  2010       10  Pelkästään polttomoottorilla ladattava     56  10.2010
# 169  2010        9  Pelkästään polttomoottorilla ladattava     29   9.2010
# 170  2010        8  Pelkästään polttomoottorilla ladattava     28   8.2010
# 171  2010        7  Pelkästään polttomoottorilla ladattava      5   7.2010
# 172  2010        6                           Ei määritelty      1   6.2010
# 173  2010        5  Pelkästään polttomoottorilla ladattava      5   5.2010
# 174  2010        4  Pelkästään polttomoottorilla ladattava      2   4.2010
# 175  2010        4                 Sähköverkosta ladattava      1   4.2010
# 176  2010        4                           Ei määritelty      1   4.2010
# 177  2010        3  Pelkästään polttomoottorilla ladattava      1   3.2010
# 178  2010        2  Pelkästään polttomoottorilla ladattava      2   2.2010
# 179  2010        1  Pelkästään polttomoottorilla ladattava      3   1.2010
# 180  2010        1                           Ei määritelty      2   1.2010
#     vuosi kuukausi            hybridityyppi  maara     date
# 1    2017       12  Sähköverkosta ladattava      2  12.2017
# 3    2017       11  Sähköverkosta ladattava      1  11.2017
# 5    2017       10  Sähköverkosta ladattava      2  10.2017
# 7    2017        9  Sähköverkosta ladattava      4   9.2017
# 9    2017        8  Sähköverkosta ladattava      8   8.2017
# 11   2017        7  Sähköverkosta ladattava      7   7.2017
# 13   2017        6  Sähköverkosta ladattava      5   6.2017
# 15   2017        5  Sähköverkosta ladattava     19   5.2017
# 17   2017        4  Sähköverkosta ladattava     16   4.2017
# 19   2017        3  Sähköverkosta ladattava     17   3.2017
# 21   2017        2  Sähköverkosta ladattava     21   2.2017
# 23   2017        1  Sähköverkosta ladattava     56   1.2017
# 25   2016       12  Sähköverkosta ladattava     62  12.2016
# 27   2016       11  Sähköverkosta ladattava     86  11.2016
# 29   2016       10  Sähköverkosta ladattava     86  10.2016
# 31   2016        9  Sähköverkosta ladattava     82   9.2016
# 33   2016        8  Sähköverkosta ladattava     64   8.2016
# 35   2016        7  Sähköverkosta ladattava     68   7.2016
# 37   2016        6  Sähköverkosta ladattava     64   6.2016
# 39   2016        5  Sähköverkosta ladattava     60   5.2016
# 41   2016        4  Sähköverkosta ladattava     56   4.2016
# 43   2016        3  Sähköverkosta ladattava     59   3.2016
# 45   2016        2  Sähköverkosta ladattava     74   2.2016
# 47   2016        1  Sähköverkosta ladattava     35   1.2016
# 49   2015       12  Sähköverkosta ladattava     36  12.2015
# 51   2015       11  Sähköverkosta ladattava     32  11.2015
# 53   2015       10  Sähköverkosta ladattava     34  10.2015
# 55   2015        9  Sähköverkosta ladattava     40   9.2015
# 57   2015        8  Sähköverkosta ladattava     37   8.2015
# 59   2015        7  Sähköverkosta ladattava     29   7.2015
# 61   2015        6  Sähköverkosta ladattava     35   6.2015
# 63   2015        5  Sähköverkosta ladattava     38   5.2015
# 65   2015        4  Sähköverkosta ladattava     38   4.2015
# 67   2015        3  Sähköverkosta ladattava     21   3.2015
# 69   2015        2  Sähköverkosta ladattava     15   2.2015
# 71   2015        1  Sähköverkosta ladattava     16   1.2015
# 73   2014       12  Sähköverkosta ladattava     24  12.2014
# 75   2014       11  Sähköverkosta ladattava     19  11.2014
# 77   2014       10  Sähköverkosta ladattava     23  10.2014
# 79   2014        9  Sähköverkosta ladattava     19   9.2014
# 81   2014        8  Sähköverkosta ladattava     23   8.2014
# 83   2014        7  Sähköverkosta ladattava     18   7.2014
# 85   2014        6  Sähköverkosta ladattava     20   6.2014
# 87   2014        5  Sähköverkosta ladattava     17   5.2014
# 89   2014        4  Sähköverkosta ladattava     26   4.2014
# 91   2014        3  Sähköverkosta ladattava     38   3.2014
# 93   2014        2  Sähköverkosta ladattava     10   2.2014
# 95   2014        1  Sähköverkosta ladattava     19   1.2014
# 97   2013       12  Sähköverkosta ladattava     19  12.2013
# 100  2013       11  Sähköverkosta ladattava     36  11.2013
# 103  2013       10  Sähköverkosta ladattava     20  10.2013
# 106  2013        9  Sähköverkosta ladattava      8   9.2013
# 109  2013        8  Sähköverkosta ladattava      3   8.2013
# 112  2013        7  Sähköverkosta ladattava      6   7.2013
# 115  2013        6  Sähköverkosta ladattava      5   6.2013
# 117  2013        5  Sähköverkosta ladattava      2   5.2013
# 119  2013        4  Sähköverkosta ladattava     13   4.2013
# 121  2013        3  Sähköverkosta ladattava     21   3.2013
# 123  2013        2  Sähköverkosta ladattava     11   2.2013
# 126  2013        1  Sähköverkosta ladattava     10   1.2013
# 129  2012       12  Sähköverkosta ladattava      4  12.2012
# 131  2012       11  Sähköverkosta ladattava      6  11.2012
# 133  2012       10  Sähköverkosta ladattava      7  10.2012
# 135  2012        9  Sähköverkosta ladattava     35   9.2012
# 137  2012        8  Sähköverkosta ladattava     24   8.2012
# 139  2012        7  Sähköverkosta ladattava     12   7.2012
# 141  2012        6  Sähköverkosta ladattava      7   6.2012
# 143  2012        5  Sähköverkosta ladattava     15   5.2012
# 145  2012        4  Sähköverkosta ladattava      4   4.2012
# 148  2012        2  Sähköverkosta ladattava      4   2.2012
# 165  2010       12  Sähköverkosta ladattava      1  12.2010
# 175  2010        4  Sähköverkosta ladattava      1   4.2010
#     vuosi kuukausi                           hybridityyppi  maara     date
# 0    2017       12  Pelkästään polttomoottorilla ladattava      4  12.2017
# 2    2017       11  Pelkästään polttomoottorilla ladattava      4  11.2017
# 4    2017       10  Pelkästään polttomoottorilla ladattava      8  10.2017
# 6    2017        9  Pelkästään polttomoottorilla ladattava     22   9.2017
# 8    2017        8  Pelkästään polttomoottorilla ladattava     32   8.2017
# 10   2017        7  Pelkästään polttomoottorilla ladattava     20   7.2017
# 12   2017        6  Pelkästään polttomoottorilla ladattava     31   6.2017
# 14   2017        5  Pelkästään polttomoottorilla ladattava     30   5.2017
# 16   2017        4  Pelkästään polttomoottorilla ladattava     42   4.2017
# 18   2017        3  Pelkästään polttomoottorilla ladattava    130   3.2017
# 20   2017        2  Pelkästään polttomoottorilla ladattava     89   2.2017
# 22   2017        1  Pelkästään polttomoottorilla ladattava    290   1.2017
# 24   2016       12  Pelkästään polttomoottorilla ladattava    288  12.2016
# 26   2016       11  Pelkästään polttomoottorilla ladattava    429  11.2016
# 28   2016       10  Pelkästään polttomoottorilla ladattava    417  10.2016
# 30   2016        9  Pelkästään polttomoottorilla ladattava    449   9.2016
# 32   2016        8  Pelkästään polttomoottorilla ladattava    478   8.2016
# 34   2016        7  Pelkästään polttomoottorilla ladattava    311   7.2016
# 36   2016        6  Pelkästään polttomoottorilla ladattava    450   6.2016
# 38   2016        5  Pelkästään polttomoottorilla ladattava    440   5.2016
# 40   2016        4  Pelkästään polttomoottorilla ladattava    401   4.2016
# 42   2016        3  Pelkästään polttomoottorilla ladattava    457   3.2016
# 44   2016        2  Pelkästään polttomoottorilla ladattava    320   2.2016
# 46   2016        1  Pelkästään polttomoottorilla ladattava    361   1.2016
# 48   2015       12  Pelkästään polttomoottorilla ladattava    258  12.2015
# 50   2015       11  Pelkästään polttomoottorilla ladattava    345  11.2015
# 52   2015       10  Pelkästään polttomoottorilla ladattava    305  10.2015
# 54   2015        9  Pelkästään polttomoottorilla ladattava    248   9.2015
# 56   2015        8  Pelkästään polttomoottorilla ladattava    239   8.2015
# 58   2015        7  Pelkästään polttomoottorilla ladattava    161   7.2015
# 60   2015        6  Pelkästään polttomoottorilla ladattava    196   6.2015
# 62   2015        5  Pelkästään polttomoottorilla ladattava    256   5.2015
# 64   2015        4  Pelkästään polttomoottorilla ladattava    270   4.2015
# 66   2015        3  Pelkästään polttomoottorilla ladattava    299   3.2015
# 68   2015        2  Pelkästään polttomoottorilla ladattava    199   2.2015
# 70   2015        1  Pelkästään polttomoottorilla ladattava    216   1.2015
# 72   2014       12  Pelkästään polttomoottorilla ladattava    183  12.2014
# 74   2014       11  Pelkästään polttomoottorilla ladattava    235  11.2014
# 76   2014       10  Pelkästään polttomoottorilla ladattava    227  10.2014
# 78   2014        9  Pelkästään polttomoottorilla ladattava    248   9.2014
# 80   2014        8  Pelkästään polttomoottorilla ladattava    221   8.2014
# 82   2014        7  Pelkästään polttomoottorilla ladattava    129   7.2014
# 84   2014        6  Pelkästään polttomoottorilla ladattava    169   6.2014
# 86   2014        5  Pelkästään polttomoottorilla ladattava    201   5.2014
# 88   2014        4  Pelkästään polttomoottorilla ladattava    145   4.2014
# 90   2014        3  Pelkästään polttomoottorilla ladattava    185   3.2014
# 92   2014        2  Pelkästään polttomoottorilla ladattava    151   2.2014
# 94   2014        1  Pelkästään polttomoottorilla ladattava    266   1.2014
# 96   2013       12  Pelkästään polttomoottorilla ladattava     92  12.2013
# 99   2013       11  Pelkästään polttomoottorilla ladattava    218  11.2013
# 102  2013       10  Pelkästään polttomoottorilla ladattava    301  10.2013
# 105  2013        9  Pelkästään polttomoottorilla ladattava    128   9.2013
# 108  2013        8  Pelkästään polttomoottorilla ladattava    225   8.2013
# 111  2013        7  Pelkästään polttomoottorilla ladattava    239   7.2013
# 114  2013        6  Pelkästään polttomoottorilla ladattava    138   6.2013
# 116  2013        5  Pelkästään polttomoottorilla ladattava    182   5.2013
# 118  2013        4  Pelkästään polttomoottorilla ladattava    151   4.2013
# 120  2013        3  Pelkästään polttomoottorilla ladattava    174   3.2013
# 122  2013        2  Pelkästään polttomoottorilla ladattava    177   2.2013
# 125  2013        1  Pelkästään polttomoottorilla ladattava    196   1.2013
# 128  2012       12  Pelkästään polttomoottorilla ladattava     93  12.2012
# 130  2012       11  Pelkästään polttomoottorilla ladattava    138  11.2012
# 132  2012       10  Pelkästään polttomoottorilla ladattava    160  10.2012
# 134  2012        9  Pelkästään polttomoottorilla ladattava     98   9.2012
# 136  2012        8  Pelkästään polttomoottorilla ladattava    137   8.2012
# 138  2012        7  Pelkästään polttomoottorilla ladattava    126   7.2012
# 140  2012        6  Pelkästään polttomoottorilla ladattava    113   6.2012
# 142  2012        5  Pelkästään polttomoottorilla ladattava     75   5.2012
# 144  2012        4  Pelkästään polttomoottorilla ladattava    120   4.2012
# 146  2012        3  Pelkästään polttomoottorilla ladattava    105   3.2012
# 147  2012        2  Pelkästään polttomoottorilla ladattava     51   2.2012
# 149  2012        1  Pelkästään polttomoottorilla ladattava    101   1.2012
# 150  2011       12  Pelkästään polttomoottorilla ladattava     38  12.2011
# 151  2011       11  Pelkästään polttomoottorilla ladattava     76  11.2011
# 153  2011       10  Pelkästään polttomoottorilla ladattava     84  10.2011
# 155  2011        9  Pelkästään polttomoottorilla ladattava    123   9.2011
# 156  2011        8  Pelkästään polttomoottorilla ladattava     66   8.2011
# 157  2011        7  Pelkästään polttomoottorilla ladattava     53   7.2011
# 158  2011        6  Pelkästään polttomoottorilla ladattava     52   6.2011
# 159  2011        5  Pelkästään polttomoottorilla ladattava    104   5.2011
# 160  2011        4  Pelkästään polttomoottorilla ladattava     84   4.2011
# 161  2011        3  Pelkästään polttomoottorilla ladattava    118   3.2011
# 162  2011        2  Pelkästään polttomoottorilla ladattava     50   2.2011
# 163  2011        1  Pelkästään polttomoottorilla ladattava     61   1.2011
# 164  2010       12  Pelkästään polttomoottorilla ladattava    104  12.2010
# 167  2010       11  Pelkästään polttomoottorilla ladattava    106  11.2010
# 168  2010       10  Pelkästään polttomoottorilla ladattava     56  10.2010
# 169  2010        9  Pelkästään polttomoottorilla ladattava     29   9.2010
# 170  2010        8  Pelkästään polttomoottorilla ladattava     28   8.2010
# 171  2010        7  Pelkästään polttomoottorilla ladattava      5   7.2010
# 173  2010        5  Pelkästään polttomoottorilla ladattava      5   5.2010
# 174  2010        4  Pelkästään polttomoottorilla ladattava      2   4.2010
# 177  2010        3  Pelkästään polttomoottorilla ladattava      1   3.2010
# 178  2010        2  Pelkästään polttomoottorilla ladattava      2   2.2010
# 179  2010        1  Pelkästään polttomoottorilla ladattava      3   1.2010

# %%
def ensirekisteroinnit_vuosittain_ominaisuuden_mukaan(ominaisuus, vuosi, luokka):
    cursor = luo_yhteys()
    query = f'''
        SELECT o.selite_fi, COUNT(ar.id) AS maara
        FROM ajoneuvorekisteroinnit ar
    	LEFT JOIN {ominaisuus} o ON o.id = ar.{ominaisuus}
        WHERE ensirekisterointipvm >= '{vuosi}-01-01' AND ensirekisterointipvm <= '{vuosi+1}-01-01' AND ar.ajoneuvoluokka = '{luokka}'
    	GROUP BY o.selite_fi
        ORDER BY maara DESC;
    '''
    try:
        cursor.execute(query)
        # Fetch and print the results
        records = cursor.fetchall()
        df = pd.DataFrame(records, columns=[ominaisuus, "maara"])
        df.fillna("Ei määritelty", inplace=True)
        print(df)
        return df
        # Commit the transaction
        #connection.commit()
    except (Exception, psycopg2.Error) as error:
        print("Error while executing SQL query:", error)

# %%
ensirekisteroinnit_vuosittain_ominaisuuden_mukaan('vari', 2016, 'M1')
ensirekisteroinnit_vuosittain_ominaisuuden_mukaan('kunta', 2016, 'M1')
ensirekisteroinnit_vuosittain_ominaisuuden_mukaan('ohjaamotyyppi', 2016, 'M1')
ensirekisteroinnit_vuosittain_ominaisuuden_mukaan('vaihteistotyyppi', 2016, 'M1')
# Out:
# <connection object at 0x000002734941E8A0; dsn: 'user=postgres password=xxx dbname=VehicleRegisterDatabase host=192.168.0.15', closed: 0>
# Cursor created successfully
#               vari  maara
# 0        Valkoinen  29691
# 1           Harmaa  27258
# 2            Musta  18938
# 3         Punainen  15141
# 4          Sininen  12691
# 5   Ruskea (beige)   9777
# 6            Hopea   7651
# 7           Vihreä   1331
# 8        Keltainen    714
# 9    Ei määritelty    584
# 10         Oranssi    517
# 11        Violetti    474
# 12        Monivär.     59
# 13        Turkoosi     30
# <connection object at 0x000002734941F120; dsn: 'user=postgres password=xxx dbname=VehicleRegisterDatabase host=192.168.0.15', closed: 0>
# Cursor created successfully
#                   kunta  maara
# 0              Helsinki  10917
# 1                 Espoo   6942
# 2                Vantaa   5535
# 3               Tampere   4889
# 4                  Oulu   4350
# 5                 Turku   3986
# 6             Jyväskylä   2996
# 7                Kuopio   2629
# 8                 Lahti   2607
# 9               Kouvola   2069
# 10                 Pori   2004
# 11            Seinäjoki   1738
# 12          Hämeenlinna   1684
# 13                Vaasa   1581
# 14         Lappeenranta   1554
# 15                 Salo   1452
# 16              Joensuu   1433
# 17               Porvoo   1413
# 18           Nurmijärvi   1358
# 19                Lohja   1316
# 20            Rovaniemi   1315
# 21            Järvenpää   1278
# 22              Tuusula   1260
# 23              Mikkeli   1232
# 24                Kotka   1207
# 25          Kirkkonummi   1174
# 26             Hyvinkää   1167
# 27              Kokkola   1020
# 28              Kaarina    985
# 29                Nokia    978
# 30             Ylöjärvi    957
# 31                Rauma    947
# 32            Kangasala    899
# 33               Kerava    876
# 34                Vihti    854
# 35            Raasepori    741
# 36           Savonlinna    711
# 37              Kajaani    700
# 38               Raisio    697
# 39                Sipoo    689
# 40            Riihimäki    684
# 41              Hollola    655
# 42             Naantali    644
# 43             Lempäälä    632
# 44               Imatra    631
# 45                Lieto    630
# 46             Mäntsälä    591
# 47            Sastamala    588
# 48             Pirkkala    580
# 49          Valkeakoski    542
# 50           Mustasaari    526
# 51               Hamina    515
# 52          Siilinjärvi    507
# 53              Varkaus    506
# 54               Tornio    481
# 55                Jämsä    468
# 56            Janakkala    461
# 57              Kempele    460
# 58              Kurikka    453
# 59                Raahe    445
# 60          Pietarsaari    441
# 61              Loviisa    425
# 62                 Akaa    424
# 63               Laukaa    415
# 64              Heinola    407
# 65              Iisalmi    407
# 66             Parainen    399
# 67         Uusikaupunki    384
# 68              Kauhava    382
# 69           Orimattila    372
# 70               Forssa    372
# 71                 Kemi    363
# 72           Pieksämäki    361
# 73            Äänekoski    359
# 74               Loimaa    358
# 75                Lapua    353
# 76            Ylivieska    348
# 77          Kontiolahti    340
# 78               Paimio    330
# 79             Ilmajoki    326
# 80               Ulvila    324
# 81           Kankaanpää    292
# 82                Masku    288
# 83              Kuusamo    286
# 84                 Eura    283
# 85     Pedersören kunta    281
# 86              Hattula    275
# 87            Kauhajoki    267
# 88             Kalajoki    264
# 89               Liperi    262
# 90               Närpiö    261
# 91              Muurame    260
# 92           Kauniainen    255
# 93              Sotkamo    251
# 94             Eurajoki    245
# 95           Hämeenkyrö    245
# 96               Somero    243
# 97              Liminka    236
# 98                Loppi    232
# 99           Leppävirta    230
# 100             Orivesi    227
# 101              Alavus    226
# 102           Huittinen    224
# 103             Siuntio    220
# 104     Mänttä-Vilppula    220
# 105            Mynämäki    213
# 106            Karkkila    210
# 107            Ulkomaat    209
# 108             Laitila    208
# 109              Pöytyä    207
# 110               Kitee    204
# 111               Rusko    204
# 112            Alajärvi    203
# 113           Hausjärvi    203
# 114              Keuruu    200
# 115              Laihia    200
# 116            Keminmaa    199
# 117            Asikkala    198
# 118                  Ii    196
# 119       Uusikaarlepyy    194
# 120          Saarijärvi    190
# 121              Säkylä    188
# 122               Muhos    186
# 123          Lapinlahti    178
# 124         Kemiönsaari    178
# 125           Sodankylä    176
# 126              Nivala    175
# 127           Pornainen    173
# 128              Lieksa    172
# 129             Kittilä    172
# 130             Tammela    166
# 131          Harjavalta    166
# 132           Ikaalinen    165
# 133               Vöyri    163
# 134                Juva    160
# 135           Kruunupyy    160
# 136               Hanko    160
# 137               Inkoo    159
# 138             Pälkäne    159
# 139               Iitti    154
# 140            Maalahti    151
# 141              Pyhtää    151
# 142             Parkano    149
# 143               Inari    149
# 144              Askola    147
# 145              Nurmes    147
# 146           Jokioinen    145
# 147          Suonenjoki    144
# 148           Kemijärvi    144
# 149  Kristiinankaupunki    140
# 150               Kuhmo    140
# 151            Oulainen    136
# 152         Taipalsaari    134
# 153             Tyrnävä    133
# 154           Kiuruvesi    132
# 155          Ruokolahti    132
# 156             Isokyrö    131
# 157          Pudasjärvi    129
# 158          Nousiainen    129
# 159              Virrat    128
# 160            Kokemäki    127
# 161         Suomussalmi    127
# 162               Teuva    126
# 163             Nakkila    126
# 164             Luumäki    123
# 165          Mäntyharju    121
# 166               Luoto    119
# 167                Aura    119
# 168         Kangasniemi    118
# 169              Ähtäri    116
# 170           Vesilahti    116
# 171          Haapajärvi    114
# 172           Outokumpu    110
# 173           Parikkala    109
# 174          Viitasaari    107
# 175              Kannus    105
# 176             Kärkölä    102
# 177              Urjala    102
# 178           Ilomantsi    100
# 179           Pyhäjärvi     99
# 180          Siikalatva     97
# 181              Joutsa     97
# 182              Kolari     96
# 183           Haapavesi     94
# 184          Petäjävesi     94
# 185            Joroinen     92
# 186               Sysmä     91
# 187           Kaustinen     89
# 188               Sievi     88
# 189           Rautjärvi     86
# 190             Ruovesi     86
# 191          Hankasalmi     86
# 192           Ylitornio     85
# 193               Pello     84
# 194            Uurainen     82
# 195               Sauvo     81
# 196           Padasjoki     81
# 197           Pielavesi     80
# 198           Siikajoki     79
# 199                Simo     78
# 200           Virolahti     76
# 201             Vieremä     76
# 202            Kuortane     76
# 203          Rantasalmi     75
# 204               Juuka     75
# 205         Taivalkoski     74
# 206                Lemi     73
# 207              Vehmaa     73
# 208            Karstula     73
# 209          Pihtipudas     73
# 210          Tohmajärvi     72
# 211            Toivakka     72
# 212          Lappajärvi     68
# 213         Savitaipale     68
# 214              Veteli     67
# 215          Merikarvia     67
# 216          Polvijärvi     67
# 217            Utajärvi     66
# 218             Puumala     66
# 219            Koski Tl     65
# 220               Ranua     64
# 221            Evijärvi     63
# 222         Punkalaidun     63
# 223           Heinävesi     62
# 224           Konnevesi     60
# 225               Salla     60
# 226               Vaala     59
# 227             Tervola     58
# 228           Toholampi     58
# 229          Lapinjärvi     57
# 230          Sonkajärvi     57
# 231             Vimpeli     57
# 232             Paltamo     56
# 233         Hirvensalmi     56
# 234              Muonio     55
# 235            Pyhäjoki     54
# 236            Humppila     54
# 237           Reisjärvi     53
# 238               Kaavi     53
# 239           Pyhäranta     53
# 240             Korsnäs     52
# 241           Alavieska     50
# 242           Juupajoki     50
# 243             Hartola     50
# 244            Lumijoki     49
# 245          Rautalampi     49
# 246               Perho     48
# 247          Hyrynsalmi     48
# 248            Pomarkku     48
# 249           Kärsämäki     48
# 250          Miehikkälä     47
# 251               Ypäjä     46
# 252            Puolanka     45
# 253             Isojoki     45
# 254               Posio     44
# 255              Karvia     44
# 256               Soini     44
# 257            Myrskylä     43
# 258             Pukkila     43
# 259           Tuusniemi     41
# 260               Tervo     41
# 261           Kuhmoinen     39
# 262              Oripää     38
# 263             Sulkava     38
# 264              Multia     37
# 265          Taivassalo     36
# 266            Rääkkylä     35
# 267             Keitele     35
# 268              Kihniö     35
# 269            Marttila     35
# 270           Enontekiö     34
# 271         Kannonkoski     31
# 272            Kyyjärvi     31
# 273             Vesanto     31
# 274            Karijoki     30
# 275             Kinnula     29
# 276           Jämijärvi     28
# 277             Pyhäntä     28
# 278           Siikainen     28
# 279           Pertunmaa     27
# 280             Utsjoki     27
# 281            Kaskinen     27
# 282             Kustavi     27
# 283          Rautavaara     26
# 284           Enonkoski     26
# 285          Ristijärvi     25
# 286       Pelkosenniemi     21
# 287              Halsua     21
# 288            Hailuoto     19
# 289             Luhanka     17
# 290           Savukoski     15
# 291           Merijärvi     14
# 292           Kivijärvi     14
# 293       Maarianhamina     12
# 294          Lestijärvi     11
# 295          Tuntematon      3
# 296              Brändö      2
# 297              Jomala      1
# 298             Saltvik      1
# <connection object at 0x000002734941D140; dsn: 'user=postgres password=xxx dbname=VehicleRegisterDatabase host=192.168.0.15', closed: 0>
# Cursor created successfully
#    ohjaamotyyppi   maara
# 0  Ei määritelty  120190
# 1    Umpiohjaamo    4385
# 2    Avo-ohjaamo     242
# 3  Jatko-ohjaamo      39
# <connection object at 0x000002734941E8A0; dsn: 'user=postgres password=xxx dbname=VehicleRegisterDatabase host=192.168.0.15', closed: 0>
# Cursor created successfully
#                 vaihteistotyyppi  maara
# 0                  Automaattinen  56784
# 1                Käsivalintainen  53667
# 2                      Portaaton  13074
# 3                  Ei määritelty   1022
# 4                            Muu    182
# 5             Ei sovellettavissa    109
# 6  Käsivalintainen/automaattinen     16
# 7           Muuttuvavälityksinen      1
# 8               Jalkavalintainen      1
#                 vaihteistotyyppi  maara
# 0                  Automaattinen  56784
# 1                Käsivalintainen  53667
# 2                      Portaaton  13074
# 3                  Ei määritelty   1022
# 4                            Muu    182
# 5             Ei sovellettavissa    109
# 6  Käsivalintainen/automaattinen     16
# 7           Muuttuvavälityksinen      1
# 8               Jalkavalintainen      1

# %%
def ensirekisterointien_maarat_ajoneuvoluokittain_aikavalilla(pvm_alku, pvm_loppu):
    cursor = luo_yhteys()
    query = f'''
        SELECT al.lyhytselite_fi, COUNT(ar.id) AS maara
        FROM ajoneuvorekisteroinnit ar
    	JOIN ajoneuvoluokka al ON al.id = ar.ajoneuvoluokka
        WHERE ensirekisterointipvm >= '{pvm_alku}' AND ensirekisterointipvm <= '{pvm_loppu}'
        GROUP BY al.lyhytselite_fi
    	ORDER BY maara DESC;
    '''
    try:
        cursor.execute(query)
        # Fetch and print the results
        records = cursor.fetchall()
        df = pd.DataFrame(records, columns=["ajoneuvoluokka", "maara"])
        df.fillna("Ei määritelty", inplace=True)
        print( df)
        return df
        
        # Commit the transaction
        #connection.commit()
    except (Exception, psycopg2.Error) as error:
        print("Error while executing SQL query:", error)

# %%
ensirekisterointien_maarat_ajoneuvoluokittain_aikavalilla('2015-01-01','2020-01-01')
ensirekisterointien_maarat_ajoneuvoluokittain_aikavalilla('2009-01-01','20150-01-01')
# Out:
# <connection object at 0x000001833470F230; dsn: 'user=postgres password=xxx dbname=VehicleRegisterDatabase host=192.168.0.15', closed: 0>
# Cursor created successfully
#           ajoneuvoluokka   maara
# 0            Henkilöauto  271686
# 1        Kevyt perävaunu   39442
# 2            Pakettiauto   30290
# 3              Perävaunu   18302
# 4               Traktori   13574
# 5                   Mopo    9449
# 6          Moottoripyörä    8356
# 7            Kuorma-auto    7178
# 8        Moottorityökone    3799
# 9         Maastoajoneuvo    3573
# 10      Liikennetraktori    2179
# 11            Linja-auto    1208
# 12       Kevyt nelipyörä     755
# 13             Nelipyörä     160
# 14            Kolmipyörä      89
# 15  Kolmi- tai nelipyörä      10
# <connection object at 0x000001833470F780; dsn: 'user=postgres password=xxx dbname=VehicleRegisterDatabase host=192.168.0.15', closed: 0>
# Cursor created successfully
#           ajoneuvoluokka   maara
# 0            Henkilöauto  947170
# 1        Kevyt perävaunu  180115
# 2            Pakettiauto  102982
# 3              Perävaunu   70601
# 4          Moottoripyörä   44620
# 5               Traktori   43800
# 6                   Mopo   40131
# 7            Kuorma-auto   26704
# 8        Moottorityökone   15240
# 9         Maastoajoneuvo   14925
# 10      Liikennetraktori    8994
# 11            Linja-auto    3734
# 12       Kevyt nelipyörä    2670
# 13             Nelipyörä    2371
# 14            Kolmipyörä     300
# 15  Kolmi- tai nelipyörä      54
#           ajoneuvoluokka   maara
# 0            Henkilöauto  947170
# 1        Kevyt perävaunu  180115
# 2            Pakettiauto  102982
# 3              Perävaunu   70601
# 4          Moottoripyörä   44620
# 5               Traktori   43800
# 6                   Mopo   40131
# 7            Kuorma-auto   26704
# 8        Moottorityökone   15240
# 9         Maastoajoneuvo   14925
# 10      Liikennetraktori    8994
# 11            Linja-auto    3734
# 12       Kevyt nelipyörä    2670
# 13             Nelipyörä    2371
# 14            Kolmipyörä     300
# 15  Kolmi- tai nelipyörä      54

# %%
def mallille_ja_merkille_korreloituvat_muuttujat(luokka):
        cursor = luo_yhteys()
    query = f'''
        SELECT al.lyhytselite_fi, COUNT(ar.id) AS maara
        FROM ajoneuvorekisteroinnit ar
    	JOIN ajoneuvoluokka al ON al.id = ar.ajoneuvoluokka
        WHERE ensirekisterointipvm >= '{pvm_alku}' AND ensirekisterointipvm <= '{pvm_loppu}'
        GROUP BY al.lyhytselite_fi
    	ORDER BY maara DESC;
    '''
    try:
        cursor.execute(query)
        # Fetch and print the results
        records = cursor.fetchall()
        df = pd.DataFrame(records, columns=["ajoneuvoluokka", "maara"])
        df.fillna("Ei määritelty", inplace=True)
        print( df)
        return df
        
        # Commit the transaction
        #connection.commit()
    except (Exception, psycopg2.Error) as error:
        print("Error while executing SQL query:", error)
