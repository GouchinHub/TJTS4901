# %%
import kuvaajakirjasto as kk

# %% [markdown]
# # Markkinatrendit

# %%
kk.hybridiajoneuvojen_maaran_kehitys(2012, 2016)

# %%
kk.top10_myydyinta_automerkkia(2017, 2022)

# %%
kk.prosentuaalinen_muutos_automerkeittain(2017, 2022)

# %%
kk.sahkoautojen_ensirekisteroinnit_merkeilla(2017, 2022, ["TESLA", "POLESTAR"])

# %% [markdown]
# # Alueelliset erot

# %%
kunnat = ["Helsinki", "Espoo","Tampere","Oulu","Kokkola","Kotka","Jyväskylä","Lahti","Kuopio","Kouvola"]
kk.rekisterointien_osuus_ajokilometriluokittain_eri_kunnissa(kunnat, 2000, 2016, 10000, 400000)

# %%
kk.top10_suurimman_merkin_markkinaosuudet_kaupungeittain(2010,2016,["Rovaniemi", "Mikkeli","Pori","Kotka" ,"Vaasa" ,"Lappeenranta"])

# %%
kunnat = ["Oulu", "Turku", "Jyväskylä", "Kuopio", "Lahti"] 
merkit = ["BMW", "Volvo", "Audi", "Skoda", "Toyota", "Volkswagen","Mercedes-Benz", "Kia"] 
kk.assosisaatio_kunnan_kayttovoiman_ja_merkin_valilla(2015, 2016, kunnat, merkit)
